# %% [markdown]
# # Análise Exploratória - Camada SILVER
#
# ## Introdução
#
# Este notebook inicia a análise exploratória dos dados da camada **SILVER** do projeto "Airline On-Time / Delay Causes".
#
# ### O que é a camada Silver?
#
# No contexto da arquitetura de **Medalhão** (Medallion Architecture):
#
# - **RAW (Bronze)**: Dados brutos, sem tratamento
# - **SILVER**: Dados limpos, padronizados e validados (onde estamos agora)
# - **GOLD**: Dados agregados e modelados para dashboards e relatórios (próximo passo)
#
# A camada SILVER contém dados que já passaram por:
# - Limpeza e padronização de colunas
# - Remoção de duplicados e colunas vazias
# - Conversão de tipos de dados
# - Tratamento de valores nulos e negativos
# - Detecção de outliers (com flags)
# - Normalização de campos categóricos
#
# ### Objetivo deste notebook
#
# Este notebook valida e explora a tabela `silver.silver_airline_on_time` para:
# 1. Verificar a qualidade dos dados após o ETL
# 2. Realizar análises exploratórias iniciais
# 3. Identificar padrões e insights preliminares
# 4. Preparar o terreno para análises mais profundas e modelagem na camada GOLD

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from sqlalchemy import create_engine, text
import warnings

warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# ## 1. Conexão com PostgreSQL
#
# Conectamos ao banco de dados PostgreSQL para acessar a tabela `silver.silver_airline_on_time`.

# %%
POSTGRES_DB = os.getenv('POSTGRES_DB', 'airline_delay_causes')
POSTGRES_USER = os.getenv('POSTGRES_USER', 'postgres')
POSTGRES_PASSWORD = os.getenv('POSTGRES_PASSWORD', 'postgres')
POSTGRES_HOST = 'localhost'
POSTGRES_PORT = 5432

connection_string = f"postgresql+psycopg2://{POSTGRES_USER}:{POSTGRES_PASSWORD}@{POSTGRES_HOST}:{POSTGRES_PORT}/{POSTGRES_DB}"

print("=" * 80)
print("Testando conexão com PostgreSQL")
print("=" * 80)
print(f"Host: {POSTGRES_HOST}:{POSTGRES_PORT}")
print(f"Database: {POSTGRES_DB}")
print(f"User: {POSTGRES_USER}")

try:
    engine = create_engine(connection_string, echo=False)
    with engine.connect() as conn:
        result = conn.execute(text("SELECT 1 as test;"))
        test_value = result.fetchone()[0]
        if test_value == 1:
            print("\nConexão estabelecida com sucesso!")
        else:
            print("\nConexão estabelecida, mas teste retornou valor inesperado.")
except Exception as e:
    print(f"\nErro ao conectar ao PostgreSQL: {e}")
    print("\nPossíveis causas:")
    print("  1. Container Docker não está rodando (execute: docker-compose up -d)")
    print("  2. Credenciais incorretas (verifique variáveis de ambiente)")
    print("  3. Porta 5432 não está acessível")
    print("  4. Banco de dados não existe")
    raise
# Out:
# ...
# Testando conexão com PostgreSQL
# ...
# Host: localhost:5432
# Database: airline_delay_causes
# User: postgres
#
# Conexão estabelecida com sucesso!

# %% [markdown]
# ## 2. Carga da Tabela Silver
#
# Carregamos a tabela `silver.silver_airline_on_time` completa para um DataFrame do Pandas.

# %%
print("=" * 80)
print("Carregando dados da tabela silver.silver_airline_on_time")
print("=" * 80)

query = "SELECT * FROM silver.silver_airline_on_time;"
df_silver = pd.read_sql(query, con=engine)

print(f"\nShape: {df_silver.shape[0]:,} linhas × {df_silver.shape[1]} colunas")
print(f"\nPrimeiras 5 linhas:")
display(df_silver.head(5))
print(f"\nInformações do DataFrame:")
df_silver.info()
# Out:
# ...
# Carregando dados da tabela silver.silver_airline_on_time
# ...
#
# Shape: 279,182 linhas × 23 colunas
#
# Primeiras 5 linhas:
#    year  month carrier          carrier_name airport  \
# 0  2004      1      DL  Delta Air Lines Inc.     PBI
# 1  2004      1      DL  Delta Air Lines Inc.     PDX
# 2  2004      1      DL  Delta Air Lines Inc.     PHL
# 3  2004      1      DL  Delta Air Lines Inc.     PHX
# 4  2004      1      DL  Delta Air Lines Inc.     PIT
#
#                                         airport_name  arr_flights  arr_del15  \
# 0  West Palm Beach/Palm Beach, FL: Palm Beach Int...          650        126
# 1               Portland, OR: Portland International          314         61
# 2       Philadelphia, PA: Philadelphia International          513         97
# 3      Phoenix, AZ: Phoenix Sky Harbor International          334         78
# 4           Pittsburgh, PA: Pittsburgh International          217         47
#
# ...

# %% [markdown]
# ## 3. Validações Rápidas Pós-ETL
#
# Realizamos verificações de qualidade dos dados para garantir que o ETL funcionou corretamente.

# %%
print("=" * 80)
print("3.1 Contagem de Nulos por Coluna (Top 15)")
print("=" * 80)

null_counts = df_silver.isnull().sum().sort_values(ascending=False)
null_counts = null_counts[null_counts > 0].head(15)

if len(null_counts) > 0:
    null_df = pd.DataFrame({
        'Coluna': null_counts.index,
        'Nulos': null_counts.values,
        'Percentual': (null_counts.values / len(df_silver) * 100).round(2)
    })
    display(null_df)
else:
    print("Nenhum valor nulo encontrado nas colunas principais.")
# Out:
# ...
# 3.1 Contagem de Nulos por Coluna (Top 15)
# ...
# Nenhum valor nulo encontrado nas colunas principais.

# %%
print("=" * 80)
print("3.2 Verificação de Duplicados")
print("=" * 80)

total_duplicates = df_silver.duplicated().sum()
print(f"Total de linhas duplicadas: {total_duplicates:,}")

if total_duplicates > 0:
    print(f"Percentual de duplicados: {(total_duplicates / len(df_silver) * 100):.2f}%")
    print("\nExemplo de linhas duplicadas:")
    display(df_silver[df_silver.duplicated(keep=False)].head(10))
else:
    print("Nenhum duplicado encontrado.")
# Out:
# ...
# 3.2 Verificação de Duplicados
# ...
# Total de linhas duplicadas: 0
# Nenhum duplicado encontrado.

# %%
print("=" * 80)
print("3.3 Estatística Descritiva (Colunas Numéricas)")
print("=" * 80)

numeric_cols = df_silver.select_dtypes(include=[np.number]).columns.tolist()
if len(numeric_cols) > 0:
    display(df_silver[numeric_cols].describe())
else:
    print("Nenhuma coluna numérica encontrada.")
# Out:
# ...
# 3.3 Estatística Descritiva (Colunas Numéricas)
# ...
#                 year          month    arr_flights      arr_del15  \
# count  279182.000000  279182.000000  279182.000000  279182.000000
# mean     2011.246391       6.499241     395.946712      77.130581
# std         4.986877       3.466929    1054.335320     206.240640
# min      2003.000000       1.000000       0.000000       0.000000
# 25%      2007.000000       3.000000      61.000000      10.000000
# 50%      2011.000000       7.000000     124.000000      25.000000
# 75%      2016.000000      10.000000     284.000000      59.000000
# max      2020.000000      12.000000   21977.000000    6377.000000
#
#           carrier_ct     weather_ct         nas_ct    security_ct  \
# count  279182.000000  279182.000000  279182.000000  279182.000000
# mean       21.644834       2.734431      25.864690       0.174087
# std        47.559493      10.333191      89.448606       0.844900
# ...

# %%
print("=" * 80)
print("3.4 Verificação de Colunas Suspeitas")
print("=" * 80)

suspicious_cols = []

for col in df_silver.columns:
    if col.lower().startswith('unnamed'):
        suspicious_cols.append((col, 'Coluna com nome "unnamed"'))
    
    null_pct = (df_silver[col].isnull().sum() / len(df_silver)) * 100
    if null_pct == 100:
        suspicious_cols.append((col, 'Coluna 100% nula'))

if len(suspicious_cols) > 0:
    print("Colunas suspeitas encontradas:")
    for col, reason in suspicious_cols:
        print(f"  - {col}: {reason}")
else:
    print("Nenhuma coluna suspeita encontrada.")
# Out:
# ...
# 3.4 Verificação de Colunas Suspeitas
# ...
# Nenhuma coluna suspeita encontrada.

# %% [markdown]
# ## 4. Análises Iniciais
#
# Realizamos análises exploratórias básicas para entender os dados e identificar padrões iniciais.

# %%
print("=" * 80)
print("4.1 Heatmap de Correlação (Colunas Numéricas)")
print("=" * 80)

numeric_cols = df_silver.select_dtypes(include=[np.number]).columns.tolist()

if len(numeric_cols) >= 2:
    corr_matrix = df_silver[numeric_cols].corr()
    
    plt.figure(figsize=(14, 10))
    sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap='coolwarm', center=0,
                square=True, linewidths=0.5, cbar_kws={"shrink": 0.8})
    plt.title('Matriz de Correlação - Colunas Numéricas', fontsize=16, pad=20)
    plt.tight_layout()
    plt.show()
else:
    print(f"É necessário pelo menos 2 colunas numéricas. Encontradas: {len(numeric_cols)}")
# Out:
# ...
# 4.1 Heatmap de Correlação (Colunas Numéricas)
# ...

# %%
print("=" * 80)
print("4.2 Distribuição da Métrica Principal (Maior Variância)")
print("=" * 80)

numeric_cols = df_silver.select_dtypes(include=[np.number]).columns.tolist()

if len(numeric_cols) > 0:
    variances = df_silver[numeric_cols].var().sort_values(ascending=False)
    main_metric = variances.index[0]
    
    print(f"Métrica selecionada: {main_metric} (variância: {variances.iloc[0]:,.2f})")
    
    fig, axes = plt.subplots(1, 2, figsize=(14, 5))
    
    axes[0].hist(df_silver[main_metric].dropna(), bins=50, edgecolor='black', alpha=0.7)
    axes[0].set_title(f'Histograma - {main_metric}', fontsize=12)
    axes[0].set_xlabel(main_metric)
    axes[0].set_ylabel('Frequência')
    axes[0].grid(True, alpha=0.3)
    
    axes[1].boxplot(df_silver[main_metric].dropna(), vert=True)
    axes[1].set_title(f'Boxplot - {main_metric}', fontsize=12)
    axes[1].set_ylabel(main_metric)
    axes[1].grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()
else:
    print("Nenhuma coluna numérica encontrada.")
# Out:
# ...
# 4.2 Distribuição da Métrica Principal (Maior Variância)
# ...
# Métrica selecionada: arr_delay (variância: 166,336,878.74)

# %%
print("=" * 80)
print("4.3 Top 10 Categóricas Mais Frequentes")
print("=" * 80)

categorical_cols = df_silver.select_dtypes(include=['object', 'string']).columns.tolist()

if len(categorical_cols) > 0:
    cardinalities = {}
    for col in categorical_cols:
        unique_count = df_silver[col].nunique()
        if 2 <= unique_count <= 100:
            cardinalities[col] = unique_count
    
    if len(cardinalities) > 0:
        selected_col = max(cardinalities, key=cardinalities.get)
        top_values = df_silver[selected_col].value_counts().head(10)
        
        print(f"Coluna selecionada: {selected_col} ({cardinalities[selected_col]} valores únicos)")
        
        plt.figure(figsize=(12, 6))
        top_values.plot(kind='bar', color='steelblue', edgecolor='black', alpha=0.7)
        plt.title(f'Top 10 - {selected_col}', fontsize=14, pad=15)
        plt.xlabel(selected_col)
        plt.ylabel('Frequência')
        plt.xticks(rotation=45, ha='right')
        plt.grid(True, alpha=0.3, axis='y')
        plt.tight_layout()
        plt.show()
        
        print("\nValores:")
        display(pd.DataFrame({
            selected_col: top_values.index,
            'Frequência': top_values.values,
            'Percentual': (top_values.values / len(df_silver) * 100).round(2)
        }))
    else:
        print("Nenhuma coluna categórica com cardinalidade adequada encontrada.")
else:
    print("Nenhuma coluna categórica encontrada.")
# Out:
# ...
# 4.3 Top 10 Categóricas Mais Frequentes
# ...
# Coluna selecionada: carrier_name (32 valores únicos)
# Valores:
#                    carrier_name  Frequência  Percentual
# 0         SkyWest Airlines Inc.       32678       11.70
# 1      ExpressJet Airlines Inc.       24670        8.84
# 2          Delta Air Lines Inc.       24511        8.78
# 3        American Airlines Inc.       17200        6.16
# 4         United Air Lines Inc.       16772        6.01
# 5  American Eagle Airlines Inc.       15409        5.52
# 6        Southwest Airlines Co.       15009        5.38
# 7            Mesa Airlines Inc.       12297        4.40
# 8   Atlantic Southeast Airlines       12204        4.37
# 9          Alaska Airlines Inc.       11057        3.96

# %%
# ============================
# 5.1 Análise de Tendências ao Longo do Tempo
# ============================

print("=" * 80)
print("5.1 Análise de Tendências ao Longo do Tempo")
print("=" * 80)

# 1) Garantir que temos uma coluna de data (flight_date) em formato datetime
#    (no seu DDL ela existe e representa o 1º dia do mês derivado de year/month)
if "flight_date" in df_silver.columns:
    df_silver["flight_date"] = pd.to_datetime(df_silver["flight_date"], errors="coerce")
else:
    # Fallback: se por algum motivo não existir, cria a data a partir de year e month
    df_silver["flight_date"] = pd.to_datetime(
        df_silver["year"].astype(str) + "-" + df_silver["month"].astype(str).str.zfill(2) + "-01",
        errors="coerce"
    )

# 2) Garantir tipos numéricos para as colunas principais (às vezes NUMERIC do Postgres vem como Decimal/object)
cols_to_numeric = ["arr_flights", "arr_del15", "arr_delay", "arr_cancelled", "arr_diverted"]
for col in cols_to_numeric:
    if col in df_silver.columns:
        df_silver[col] = pd.to_numeric(df_silver[col], errors="coerce")

# 3) Agregar por mês (somando tudo que já está particionado por carrier/airport)
#    - arr_flights: total de voos no mês
#    - arr_del15: total de voos com atraso >=15
#    - arr_delay: total de minutos de atraso no mês (soma)
#    - arr_cancelled/arr_diverted: totais no mês (se existirem)
agg_dict = {
    "arr_flights": "sum",
    "arr_del15": "sum",
    "arr_delay": "sum"
}
if "arr_cancelled" in df_silver.columns:
    agg_dict["arr_cancelled"] = "sum"
if "arr_diverted" in df_silver.columns:
    agg_dict["arr_diverted"] = "sum"

df_time = (
    df_silver
    .dropna(subset=["flight_date"])
    .groupby("flight_date", as_index=False)
    .agg(agg_dict)
    .sort_values("flight_date")
)

# 4) Criar métricas normalizadas (evita o viés de “mais voos = mais atraso total”)
#    - delay_rate: taxa de voos com atraso >=15 (arr_del15 / arr_flights)
#    - delay_per_flight: minutos de atraso por voo (arr_delay / arr_flights)
df_time["delay_rate"] = np.where(df_time["arr_flights"] > 0, df_time["arr_del15"] / df_time["arr_flights"], np.nan)
df_time["delay_per_flight"] = np.where(df_time["arr_flights"] > 0, df_time["arr_delay"] / df_time["arr_flights"], np.nan)

print(f"\nPeríodo: {df_time['flight_date'].min().date()} até {df_time['flight_date'].max().date()}")
print(f"Total de meses: {df_time.shape[0]}")

# 5) Plot 1: Total de voos ao longo do tempo
plt.figure(figsize=(14, 6))
plt.plot(df_time["flight_date"], df_time["arr_flights"])
plt.title("Tendência: Total de Voos (arr_flights) por Mês", fontsize=14, pad=12)
plt.xlabel("Mês")
plt.ylabel("Total de voos (chegadas)")
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# 6) Plot 2: Total de minutos de atraso ao longo do tempo
plt.figure(figsize=(14, 6))
plt.plot(df_time["flight_date"], df_time["arr_delay"])
plt.title("Tendência: Total de Minutos de Atraso (arr_delay) por Mês", fontsize=14, pad=12)
plt.xlabel("Mês")
plt.ylabel("Minutos totais de atraso")
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# 7) Plot 3: Métrica normalizada (taxa de atraso >= 15 min)
plt.figure(figsize=(14, 6))
plt.plot(df_time["flight_date"], df_time["delay_rate"])
plt.title("Tendência: Taxa de Atraso (arr_del15 / arr_flights) por Mês", fontsize=14, pad=12)
plt.xlabel("Mês")
plt.ylabel("Taxa de atraso (>=15 min)")
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

print("\nResumo rápido (últimos 6 meses do período):")
display(df_time.tail(6))
# Out:
# ...
# 5.1 Análise de Tendências ao Longo do Tempo
# ...
#
# Período: 2003-06-01 até 2020-03-01
# Total de meses: 202
# Resumo rápido (últimos 6 meses do período):
#     flight_date  arr_flights  arr_del15  arr_delay  arr_cancelled  \
# 196  2019-10-01       636014     105046  6543736.0           5172
# 197  2019-11-01       602453      85651  5334273.0           4446
# 198  2019-12-01       625763     126945  8584420.0           5793
# 199  2020-01-01       607346      82285  5283250.0           6928
# 200  2020-02-01       574268      84616  5819054.0           5135
# 201  2020-03-01       648233      53720  3248251.0         110191
#
#      arr_diverted  delay_rate  delay_per_flight
# 196          1205    0.165163         10.288667
# 197           900    0.142170          8.854256
# 198          1358    0.202864         13.718325
# 199          1150    0.135483          8.698913
# 200          1057    0.147346         10.132994
# 201           797    0.082871          5.010931

# %%
# ============================
# 5.2 Sazonalidade (versão simples)
# ============================

print("=" * 80)
print("5.2 Sazonalidade (Simples)")
print("=" * 80)

df_time["month"] = df_time["flight_date"].dt.month

# Média por mês (1..12) ao longo do período
season = (df_time
          .groupby("month", as_index=False)[["delay_rate", "delay_per_flight"]]
          .mean()
          .sort_values("month"))

# Um único gráfico (sazonalidade)
plt.figure(figsize=(10, 4))
plt.plot(season["month"], season["delay_rate"], marker="o")
plt.title("Sazonalidade: taxa média de atraso por mês")
plt.xlabel("Mês")
plt.ylabel("Taxa média")
plt.xticks(range(1, 13))
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

print("\nTop 5 meses com maior taxa média de atraso:")
display(season.sort_values("delay_rate", ascending=False).head(5))
# Out:
# ...
# 5.2 Sazonalidade (Simples)
# ...
# Top 5 meses com maior taxa média de atraso:
#     month  delay_rate  delay_per_flight
# 11     12    0.234678         13.413053
# 5       6    0.230507         14.102553
# 6       7    0.224552         13.918715
# 7       8    0.203489         12.072169
# 1       2    0.198369         11.256839

# %% [markdown]
# ## 5. Validações e KPIs
#
# Realizamos validações adicionais e calculamos KPIs essenciais para garantir a consistência da camada Silver e gerar métricas comparáveis.

# %% [markdown]
# ### 5.1 Validações de integridade (regras básicas)
# Esse trecho faz um “check rápido de bom senso” nos dados. Ele procura erros óbvios como: número de atrasos maior que número de voos, valores negativos em colunas que deveriam ser contagens, mês fora de 1 a 12, ano estranho. Se achar problema, ele mostra quantos registros estão errados e exemplos.

# %%
# 5.1 Validações de integridade (regras básicas)
print("=" * 80)
print("5.1 Validações de Integridade (Regras Básicas)")
print("=" * 80)

rules = []

# Regras simples (domínio)
if {"arr_del15", "arr_flights"}.issubset(df_silver.columns):
    rules.append(("arr_del15 <= arr_flights", (df_silver["arr_del15"] <= df_silver["arr_flights"])))

for col in ["arr_flights", "arr_del15", "arr_cancelled", "arr_diverted"]:
    if col in df_silver.columns:
        rules.append((f"{col} >= 0", (df_silver[col] >= 0)))

if "month" in df_silver.columns:
    rules.append(("month entre 1 e 12", df_silver["month"].between(1, 12)))

if "year" in df_silver.columns:
    rules.append(("year >= 1900", df_silver["year"] >= 1900))

# Consolidar resultados
if rules:
    results = []
    for name, mask in rules:
        mask = mask.fillna(False)
        invalid_count = (~mask).sum()
        results.append({
            "Regra": name,
            "Inválidos": int(invalid_count),
            "% Inválidos": round((invalid_count / len(df_silver)) * 100, 4) if len(df_silver) else 0
        })

    df_rules = pd.DataFrame(results).sort_values("Inválidos", ascending=False)
    display(df_rules)

    # Mostrar exemplos se houver inválidos
    if df_rules["Inválidos"].sum() > 0:
        print("\nExemplos (até 10 linhas) de registros que violam alguma regra:")
        invalid_any = pd.Series(False, index=df_silver.index)
        for _, mask in rules:
            invalid_any = invalid_any | (~mask.fillna(False))
        display(df_silver.loc[invalid_any].head(10))
    else:
        print("\n✓ Nenhuma violação encontrada nas regras básicas.")
else:
    print("Nenhuma regra pôde ser aplicada (colunas esperadas não encontradas).")
# Out:
# ...
# 5.1 Validações de Integridade (Regras Básicas)
# ...
#                       Regra  Inválidos  % Inválidos
# 0  arr_del15 <= arr_flights          0          0.0
# 1          arr_flights >= 0          0          0.0
# 2            arr_del15 >= 0          0          0.0
# 3        arr_cancelled >= 0          0          0.0
# 4         arr_diverted >= 0          0          0.0
# 5        month entre 1 e 12          0          0.0
# 6              year >= 1900          0          0.0
# ✓ Nenhuma violação encontrada nas regras básicas.

# %% [markdown]
# ### 5.2 Unicidade da granularidade (PK composta)
# Para cada combinação (year, month, carrier, airport) deveria existir só 1 linha. Ele procura repetições dessa chave. Se tiver repetido, ele mostra quais chaves estão duplicadas e exemplos de linhas repetidas.

# %%
# 5.2 Checagem de unicidade da granularidade (PK composta)
print("=" * 80)
print("5.2 Unicidade da Granularidade (year, month, carrier, airport)")
print("=" * 80)

pk_cols = ["year", "month", "carrier", "airport"]

if set(pk_cols).issubset(df_silver.columns):
    # Linhas com chave repetida
    dup_mask = df_silver.duplicated(subset=pk_cols, keep=False)
    dup_count = int(dup_mask.sum())

    print(f"Total de registros: {len(df_silver)}")
    print(f"Registros com chave repetida: {dup_count} ({round((dup_count/len(df_silver))*100, 4) if len(df_silver) else 0}%)")

    if dup_count > 0:
        print("\nExemplos de chaves repetidas (até 10):")
        display(df_silver.loc[dup_mask, pk_cols].value_counts().head(10).reset_index(name="Ocorrências"))

        print("\nExemplos de linhas duplicadas pela chave (até 10):")
        display(df_silver.loc[dup_mask].sort_values(pk_cols).head(10))
    else:
        print("\n✓ Nenhuma duplicidade encontrada para a granularidade (year, month, carrier, airport).")
else:
    missing = [c for c in pk_cols if c not in df_silver.columns]
    print(f"Não foi possível checar unicidade. Colunas ausentes: {missing}")
# Out:
# ...
# 5.2 Unicidade da Granularidade (year, month, carrier, airport)
# ...
# Total de registros: 279182
# Registros com chave repetida: 0 (0.0%)
#
# ✓ Nenhuma duplicidade encontrada para a granularidade (year, month, carrier, airport).

# %% [markdown]
# ### 5.3 Completude temporal (buracos no período)
# Verifica se está faltando algum mês dentro do intervalo de tempo que a tabela cobre. Ele descobre o primeiro e o último mês presentes, monta a lista de todos os meses que deveriam existir entre eles e compara com o que está na Silver. Se faltar algum mês, lista quais.

# %%
# 5.3 Completude temporal (buracos no período)
print("=" * 80)
print("5.3 Completude Temporal (Buracos no Período)")
print("=" * 80)

# Garantir uma coluna de data mensal
if "flight_date" in df_silver.columns:
    df_silver["flight_date"] = pd.to_datetime(df_silver["flight_date"], errors="coerce")
else:
    df_silver["flight_date"] = pd.to_datetime(
        df_silver["year"].astype(str) + "-" + df_silver["month"].astype(str).str.zfill(2) + "-01",
        errors="coerce"
    )

df_months = (df_silver
             .dropna(subset=["flight_date"])
             .assign(flight_month=lambda x: x["flight_date"].dt.to_period("M").dt.to_timestamp())
             [["flight_month"]]
             .drop_duplicates()
             .sort_values("flight_month"))

if df_months.empty:
    print("Não foi possível avaliar completude temporal (flight_date inválida ou ausente).")
else:
    start = df_months["flight_month"].min()
    end = df_months["flight_month"].max()

    expected = pd.date_range(start=start, end=end, freq="MS")  # Month Start
    observed = set(df_months["flight_month"])
    missing = [d for d in expected if d not in observed]

    print(f"Período observado: {start.date()} até {end.date()}")
    print(f"Meses esperados no intervalo: {len(expected)}")
    print(f"Meses presentes na Silver: {len(df_months)}")
    print(f"Meses faltando: {len(missing)}")

    if missing:
        df_missing = pd.DataFrame({"Meses_Faltando": missing})
        display(df_missing.head(24))
    else:
        print("\n✓ Nenhum mês faltando no intervalo observado.")
# Out:
# ...
# 5.3 Completude Temporal (Buracos no Período)
# ...
# Período observado: 2003-06-01 até 2020-03-01
# Meses esperados no intervalo: 202
# Meses presentes na Silver: 202
# Meses faltando: 0
#
# ✓ Nenhum mês faltando no intervalo observado.

# %% [markdown]
# ### 5.4 KPIs derivados (mínimos)
# Cria números mais fáceis de comparar. Em vez de olhar só totais brutos (que enganam quando tem mais voos), calcula: porcentagem de voos com atraso ≥ 15 min (taxa de atraso) e minutos médios de atraso por voo. Mostra esses KPIs por mês e destaca rapidamente meses melhores e piores.

# %%
# 5.4 KPIs derivados mínimos (normalização)
print("=" * 80)
print("5.4 KPIs Derivados (Mínimos)")
print("=" * 80)

df_silver.columns = df_silver.columns.astype(str).str.strip()

kpi_cols = ["arr_flights", "arr_del15", "arr_delay", "arr_cancelled", "arr_diverted"]
existing = [c for c in kpi_cols if c in df_silver.columns]

# Converte numérico (NUMERIC/Decimal -> float/int) e agrega por mês
df_silver[existing] = df_silver[existing].apply(pd.to_numeric, errors="coerce")

df_kpi = (df_silver
          .groupby(["year", "month"], as_index=False)[existing]
          .sum())

df_kpi["flight_month"] = pd.to_datetime(
    df_kpi["year"].astype(str) + "-" + df_kpi["month"].astype(str).str.zfill(2) + "-01",
    errors="coerce"
)

df_kpi = df_kpi.sort_values("flight_month")

if "arr_flights" not in df_kpi.columns:
    print("Não foi possível calcular KPIs (arr_flights ausente).")
else:
    f = df_kpi["arr_flights"]

    # KPIs principais
    df_kpi["delay_rate"] = np.where(f > 0, df_kpi.get("arr_del15", 0) / f, np.nan)
    df_kpi["delay_per_flight"] = np.where(f > 0, df_kpi.get("arr_delay", 0) / f, np.nan)

    # KPIs opcionais
    if "arr_cancelled" in df_kpi.columns:
        df_kpi["cancel_rate"] = np.where(f > 0, df_kpi["arr_cancelled"] / f, np.nan)
    if "arr_diverted" in df_kpi.columns:
        df_kpi["divert_rate"] = np.where(f > 0, df_kpi["arr_diverted"] / f, np.nan)

    # Saída limpa (últimos 12 meses)
    show = df_kpi[["flight_month", "delay_rate", "delay_per_flight", "arr_flights"]].tail(12).copy()
    show["delay_rate"] = (show["delay_rate"] * 100).round(2)
    show["delay_per_flight"] = show["delay_per_flight"].round(2)
    show["arr_flights"] = show["arr_flights"].astype("int64")
    show.columns = ["mes", "taxa_atraso_% (>=15m)", "atraso_medio_min/voo", "voos"]

    print("KPIs (últimos 12 meses):")
    display(show)

    # Top 3 melhores/piores meses (pela taxa)
    best = df_kpi.nsmallest(3, "delay_rate")[["flight_month", "delay_rate", "delay_per_flight"]].copy()
    worst = df_kpi.nlargest(3, "delay_rate")[["flight_month", "delay_rate", "delay_per_flight"]].copy()

    for t in (best, worst):
        t["delay_rate"] = (t["delay_rate"] * 100).round(2)
        t["delay_per_flight"] = t["delay_per_flight"].round(2)

    print("\nTop 3 melhores meses (menor taxa de atraso):")
    display(best.rename(columns={"flight_month": "mes", "delay_rate": "taxa_atraso_%", "delay_per_flight": "atraso_min/voo"}))

    print("\nTop 3 piores meses (maior taxa de atraso):")
    display(worst.rename(columns={"flight_month": "mes", "delay_rate": "taxa_atraso_%", "delay_per_flight": "atraso_min/voo"}))
# Out:
# ...
# 5.4 KPIs Derivados (Mínimos)
# ...
# KPIs (últimos 12 meses):
#            mes  taxa_atraso_% (>=15m)  atraso_medio_min/voo    voos
# 190 2019-04-01                  17.73                 12.54  612023
# 191 2019-05-01                  19.84                 13.95  636390
# 192 2019-06-01                  24.09                 17.44  636691
# 193 2019-07-01                  20.58                 15.69  659029
# 194 2019-08-01                  20.24                 14.54  658461
# 195 2019-09-01                  13.79                  9.15  605979
# 196 2019-10-01                  16.52                 10.29  636014
# 197 2019-11-01                  14.22                  8.85  602453
# 198 2019-12-01                  20.29                 13.72  625763
# 199 2020-01-01                  13.55                  8.70  607346
# 200 2020-02-01                  14.73                 10.13  574268
# 201 2020-03-01                   8.29                  5.01  648233
# ...

# %% [markdown]
# ### 5.5 Resumindo os números por companhia aérea e por aeroporto.
# Calcula duas medidas simples para comparar de forma justa:
#
# - “Qual porcentagem dos voos atrasou 15 minutos ou mais?” (taxa de atraso).
# - “Em média, quantos minutos cada voo atrasou?” (atraso médio por voo).

# %%
# 5.5 Rankings (carrier e airport) usando KPIs
print("=" * 80)
print("5.5 Rankings por Carrier e Airport (com KPIs)")
print("=" * 80)

df_silver.columns = df_silver.columns.astype(str).str.strip()

needed = ["arr_flights", "arr_del15", "arr_delay"]
if not set(needed).issubset(df_silver.columns):
    missing = [c for c in needed if c not in df_silver.columns]
    print(f"Não foi possível gerar rankings. Colunas ausentes: {missing}")
else:
    # Tipagem numérica
    for c in ["arr_flights", "arr_del15", "arr_delay", "arr_cancelled", "arr_diverted"]:
        if c in df_silver.columns:
            df_silver[c] = pd.to_numeric(df_silver[c], errors="coerce")

    # Agrega e calcula KPIs (mantendo simples)
    def build_rank(df, group_col):
        base = ["arr_flights", "arr_del15", "arr_delay"]
        extra = [c for c in ["arr_cancelled", "arr_diverted"] if c in df.columns]
        cols = base + extra

        out = df.groupby(group_col, as_index=False)[cols].sum()

        f = out["arr_flights"]
        out["delay_rate"] = np.where(f > 0, out["arr_del15"] / f, np.nan)
        out["delay_per_flight"] = np.where(f > 0, out["arr_delay"] / f, np.nan)

        if "arr_cancelled" in out.columns:
            out["cancel_rate"] = np.where(f > 0, out["arr_cancelled"] / f, np.nan)
        if "arr_diverted" in out.columns:
            out["divert_rate"] = np.where(f > 0, out["arr_diverted"] / f, np.nan)

        return out

    # Formata e reduz colunas para exibição
    def show_top(df_rank, key_col, metric_col, title):
        top = df_rank.sort_values(metric_col, ascending=False).head(10).copy()

        # Saída: só o que importa para entender ranking
        out = top[[key_col, "arr_flights", metric_col]].copy()

        if metric_col == "delay_rate":
            out[metric_col] = (out[metric_col] * 100).round(2)
            out = out.rename(columns={metric_col: "taxa_atraso_% (>=15m)"})
        else:
            out[metric_col] = out[metric_col].round(2)
            out = out.rename(columns={metric_col: "atraso_medio_min/voo"})

        out["arr_flights"] = out["arr_flights"].astype("int64")
        out = out.rename(columns={key_col: key_col, "arr_flights": "voos"})

        print(f"\n{title}")
        display(out)

    # Carrier
    if "carrier" in df_silver.columns:
        carrier_rank = build_rank(df_silver.dropna(subset=["carrier"]), "carrier")
        show_top(carrier_rank, "carrier", "delay_rate", "Top 10 carriers (pior taxa de atraso)")
        show_top(carrier_rank, "carrier", "delay_per_flight", "Top 10 carriers (maior atraso médio por voo)")
    else:
        print("\nColuna 'carrier' não encontrada. Pulando ranking por carrier.")


    # Airport
    if "airport" in df_silver.columns:
        airport_rank = build_rank(df_silver.dropna(subset=["airport"]), "airport")
        show_top(airport_rank, "airport", "delay_rate", "Top 10 aeroportos (pior taxa de atraso)")
        show_top(airport_rank, "airport", "delay_per_flight", "Top 10 aeroportos (maior atraso médio por voo)")
    else:
        print("\nColuna 'airport' não encontrada. Pulando ranking por airport.")
# Out:
# ...
# 5.5 Rankings por Carrier e Airport (com KPIs)
# ...
#
# Top 10 carriers (pior taxa de atraso)
#    carrier     voos  taxa_atraso_% (>=15m)
# 4       B6  3641652                  23.58
# 8       EV  6476795                  22.49
# 9       F9  1413082                  22.30
# 16      NW  2767549                  22.04
# 5       CO  2447164                  21.95
# 25      XE  2145095                  21.83
# 19      RU  1185570                  21.73
# 17      OH  2406015                  21.64
# 14      MQ  6472251                  21.63
# 11      G4   229768                  20.85
# Top 10 carriers (maior atraso médio por voo)
#    carrier     voos  atraso_medio_min/voo
# 4       B6  3641652                 15.32
# 11      G4   229768                 14.92
# 8       EV  6476795                 14.57
# 15      NK   847989                 13.95
# 25      XE  2145095                 13.58
# 26      YV  2199990                 12.98
# 9       F9  1413082                 12.86
# ...

# %% [markdown]
# ## 6. Metadados rápidos da Silver (visão geral)
# Aqui há quantas linhas e colunas ela tem, qual é o período coberto (data inicial e final), quantas companhias e quantos aeroportos diferentes aparecem, e quantas combinações únicas existem para (year, month, carrier, airport). Útil para conferir rapidamente se o dataset está completo e no tamanho esperado.

# %%
# 6. Metadados rápidos da Silver (visão geral)
print("=" * 80)
print("6.0 Metadados Rápidos da Silver (Visão Geral)")
print("=" * 80)

df_silver.columns = df_silver.columns.astype(str).str.strip()

# Período (preferir flight_date; fallback para year/month)
if "flight_date" in df_silver.columns:
    df_silver["flight_date"] = pd.to_datetime(df_silver["flight_date"], errors="coerce")
    start_date = df_silver["flight_date"].min()
    end_date = df_silver["flight_date"].max()
else:
    start_date = pd.to_datetime(
        df_silver["year"].astype(str) + "-" + df_silver["month"].astype(str).str.zfill(2) + "-01",
        errors="coerce"
    ).min()
    end_date = pd.to_datetime(
        df_silver["year"].astype(str) + "-" + df_silver["month"].astype(str).str.zfill(2) + "-01",
        errors="coerce"
    ).max()

# Granularidade e cardinalidades
meta = {
    "Linhas (registros)": len(df_silver),
    "Colunas": df_silver.shape[1],
}

if "carrier" in df_silver.columns:
    meta["Carriers distintos"] = int(df_silver["carrier"].nunique(dropna=True))
if "airport" in df_silver.columns:
    meta["Aeroportos distintos"] = int(df_silver["airport"].nunique(dropna=True))

# Quantidade de chaves únicas (ajuda a provar granularidade)
pk_cols = ["year", "month", "carrier", "airport"]
if set(pk_cols).issubset(df_silver.columns):
    meta["Chaves únicas (year,month,carrier,airport)"] = int(df_silver[pk_cols].drop_duplicates().shape[0])

# Exibir período de forma bonita
meta["Período (início)"] = start_date.date() if pd.notna(start_date) else None
meta["Período (fim)"] = end_date.date() if pd.notna(end_date) else None

display(pd.DataFrame([meta]))
# Out:
# ...
# 6.0 Metadados Rápidos da Silver (Visão Geral)
# ...
#    Linhas (registros)  Colunas  Carriers distintos  Aeroportos distintos  \
# 0              279182       23                  28                   409
#
#    Chaves únicas (year,month,carrier,airport) Período (início) Período (fim)
# 0                                      279182       2003-06-01    2020-03-01

# %% [markdown]
# ## 7. Causas de atraso
# Analisamos as colunas de causas de atraso para entender “por que” os atrasos acontecem. Primeiro medimos a participação de cada causa no total do período (preferindo minutos *_delay, com fallback para contagens *_ct). Em seguida, identificamos a causa dominante por companhia aérea e por aeroporto, mostrando quais causas mais contribuem para os atrasos nos maiores volumes.

# %%
# 7. Preparando colunas e tipos
print("=" * 80)
print("7. Causas de Atraso (Setup)")
print("=" * 80)

df_silver.columns = df_silver.columns.astype(str).str.strip()

cause_delay_cols = ["carrier_delay", "weather_delay", "nas_delay", "security_delay", "late_aircraft_delay"]
cause_ct_cols    = ["carrier_ct", "weather_ct", "nas_ct", "security_ct", "late_aircraft_ct"]

use_cols = [c for c in cause_delay_cols if c in df_silver.columns]
unit = "minutos"

if not use_cols:
    use_cols = [c for c in cause_ct_cols if c in df_silver.columns]
    unit = "ocorrências"

print(f"Colunas usadas: {use_cols} | Unidade: {unit}")

if not use_cols:
    print("Não foi possível analisar causas: não encontrei colunas *_delay nem *_ct.")
else:
    for c in use_cols:
        df_silver[c] = pd.to_numeric(df_silver[c], errors="coerce").fillna(0)
# Out:
# ...
# 7. Causas de Atraso (Setup)
# ...
# Colunas usadas: ['carrier_delay', 'weather_delay', 'nas_delay', 'security_delay', 'late_aircraft_delay'] | Unidade: minutos

# %%
# Participação das causas (tabela + gráfico)
if not use_cols:
    print("Sem colunas de causa para analisar.")
else:
    total_by_cause = df_silver[use_cols].sum().sort_values(ascending=False)
    total_all = float(total_by_cause.sum())

    df_cause_share = (total_by_cause
                      .reset_index()
                      .rename(columns={"index": "Causa", 0: f"Total_{unit}"}))

    df_cause_share["Percentual"] = np.where(
        total_all > 0,
        (df_cause_share[f"Total_{unit}"] / total_all) * 100,
        np.nan
    ).round(2)

    print(f"\n7.1 Participação das causas no total ({unit}):")
    display(df_cause_share)

    plt.figure(figsize=(10, 4))
    plt.bar(df_cause_share["Causa"], df_cause_share["Percentual"])
    plt.title(f"Participação das causas no total ({unit})")
    plt.xlabel("Causa")
    plt.ylabel("Percentual (%)")
    plt.xticks(rotation=30, ha="right")
    plt.tight_layout()
    plt.show()
# Out:
# 7.1 Participação das causas no total (minutos):
#                  Causa  Total_minutos  Percentual
# 0  late_aircraft_delay    471968163.0       38.27
# 1        carrier_delay    364055403.0       29.52
# 2            nas_delay    331766662.0       26.90
# 3        weather_delay     63376346.0        5.14
# 4       security_delay      1958431.0        0.16

# %%
# Causa dominante (Top 5) por carrier e airport
if not use_cols:
    print("Sem colunas de causa para analisar.")
else:
    def dominant_cause_by(group_col, top_n=5):
        if group_col not in df_silver.columns:
            print(f"Coluna '{group_col}' não encontrada. Pulando.")
            return

        grp = df_silver.groupby(group_col, as_index=False)[use_cols].sum()
        grp[f"total_{unit}"] = grp[use_cols].sum(axis=1)

        grp["causa_dominante"] = grp[use_cols].idxmax(axis=1)
        grp[f"dominante_{unit}"] = grp[use_cols].max(axis=1)

        grp["dominante_%"] = np.where(
            grp[f"total_{unit}"] > 0,
            (grp[f"dominante_{unit}"] / grp[f"total_{unit}"]) * 100,
            np.nan
        ).round(2)

        out = grp.sort_values(f"total_{unit}", ascending=False).head(top_n)
        cols_show = [group_col, f"total_{unit}", "causa_dominante", f"dominante_{unit}", "dominante_%"]

        print(f"\n7.2 Causa dominante por {group_col} (top {top_n} por total de {unit}):")
        display(out[cols_show])

    dominant_cause_by("carrier", top_n=5)
    dominant_cause_by("airport", top_n=5)
# Out:
# 7.2 Causa dominante por carrier (top 5 por total de minutos):
#    carrier  total_minutos      causa_dominante  dominante_minutos  dominante_%
# 24      WN    178840565.0  late_aircraft_delay         97228785.0        54.37
# 1       AA    143124383.0  late_aircraft_delay         51160953.0        35.75
# 7       DL    114799609.0        carrier_delay         39057537.0        34.02
# 18      OO    113540231.0  late_aircraft_delay         45741709.0        40.29
# 21      UA    105363415.0  late_aircraft_delay         42519299.0        40.35
# 7.2 Causa dominante por airport (top 5 por total de minutos):
#     airport  total_minutos      causa_dominante  dominante_minutos  \
# 278     ORD     85123001.0            nas_delay         35875433.0
# 22      ATL     77687817.0            nas_delay         25911435.0
# 101     DFW     53129426.0  late_aircraft_delay         21729741.0
# 126     EWR     44745726.0            nas_delay         25955803.0
# ...
